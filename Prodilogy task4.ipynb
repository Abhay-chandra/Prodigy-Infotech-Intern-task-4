# %%
import pandas as pd 
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import re
import string
import nltk

# %%
df = pd.read_excel('twitter comments.xlsx')
df
# Out:
#        number      company  emotions  \
# 0        2401  Borderlands  Positive
# 1        2401  Borderlands  Positive
# 2        2401  Borderlands  Positive
# 3        2401  Borderlands  Positive
# 4        2401  Borderlands  Positive
# ...       ...          ...       ...
# 74677    9200       Nvidia  Positive
# 74678    9200       Nvidia  Positive
# 74679    9200       Nvidia  Positive
# 74680    9200       Nvidia  Positive
# 74681    9200       Nvidia  Positive
#
#                                                 comments
# 0      im getting on borderlands and i will murder yo...
# 1      I am coming to the borders and I will kill you...
# 2      im getting on borderlands and i will kill you ...
# 3      im coming on borderlands and i will murder you...
# 4      im getting on borderlands 2 and i will murder ...
# ...                                                  ...
# 74677  Just realized that the Windows partition of my...
# 74678  Just realized that my Mac window partition is ...
# 74679  Just realized the windows partition of my Mac ...
# 74680  Just realized between the windows partition of...
# 74681  Just like the windows partition of my Mac is l...
#
# [74682 rows x 4 columns]

# %%
#remove special char number and punctuation
df['comments'] = df['comments'].str.replace("[^a-zA-Z#]"," ")
df.head()
# Out:
# C:\Users\Abhay chandra\AppData\Local\Temp\ipykernel_8112\1367927691.py:2: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['comments'] = df['comments'].str.replace("[^a-zA-Z#]"," ")
#    number      company  emotions  \
# 0    2401  Borderlands  Positive
# 1    2401  Borderlands  Positive
# 2    2401  Borderlands  Positive
# 3    2401  Borderlands  Positive
# 4    2401  Borderlands  Positive
#
#                                             comments
# 0  im getting on borderlands and i will murder yo...
# 1  I am coming to the borders and I will kill you...
# 2  im getting on borderlands and i will kill you ...
# 3  im coming on borderlands and i will murder you...
# 4  im getting on borderlands   and i will murder ...

# %%
df['comments'] = df['comments'].astype(str)

# %%
df['comments'] = df['comments'].fillna('')

# %%
#individual words considered as token
tokenized_tweets = df['comments'].apply(lambda x: x.split())
tokenized_tweets.head()
# Out:
# 0    [im, getting, on, borderlands, and, i, will, m...
# 1    [I, am, coming, to, the, borders, and, I, will...
# 2    [im, getting, on, borderlands, and, i, will, k...
# 3    [im, coming, on, borderlands, and, i, will, mu...
# 4    [im, getting, on, borderlands, and, i, will, m...
# Name: comments, dtype: object

# %%
#visualize most frequent word used
from wordcloud import WordCloud
all_words= " " .join([sentence for sentence in df['comments']])
wordcloud = WordCloud(width=800, height=500, random_state=42, max_font_size=100).generate(all_words)
plt.figure(figsize=(15, 8))
plt.imshow(wordcloud, interpolation='bilinear')
plt.axis('off') 
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 74682 entries, 0 to 74681
# Data columns (total 4 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   number    74682 non-null  int64
#  1   company   74682 non-null  object
#  2   emotions  74682 non-null  object
#  3   comments  74682 non-null  object
# dtypes: int64(1), object(3)
# memory usage: 2.3+ MB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(10, 6))
sns.countplot(x='emotions', data=df, palette='pastel', hue='emotions')
plt.title('Sentiment Analysis')
plt.xlabel('Emotions')
plt.ylabel('Count')
plt.legend(title='Emotions')  # Add legend separately
plt.show()

# %%
#pie
emotion_counts = df['emotions'].value_counts()
plt.figure(figsize=(10, 6))
plt.pie(emotion_counts, labels=emotion_counts.index, autopct='%1.1f%%', colors=sns.color_palette('pastel'))
plt.title('Sentiment Analysis Distribution')
plt.show()

# %%
df.describe()
# Out:
#              number
# count  74682.000000
# mean    6432.586165
# std     3740.427870
# min        1.000000
# 25%     3195.000000
# 50%     6422.000000
# 75%     9601.000000
# max    13200.000000
